# %% [markdown]
# <a href="https://colab.research.google.com/github/sasumwen/housing_in_mexico/blob/main/010_housing_in_mexico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df1 = pd.read_csv("/content/drive/MyDrive/colab_notebooks/010-housing_in_mexico/mexico-real-estate-1.csv", encoding="ISO-8859-1")

# %%
df2 = pd.read_csv("/content/drive/MyDrive/colab_notebooks/010-housing_in_mexico/mexico-real-estate-2.csv", encoding="ISO-8859-1")
df3 = pd.read_csv("/content/drive/MyDrive/colab_notebooks/010-housing_in_mexico/mexico-real-estate-3.csv", encoding="ISO-8859-1")

# %%
df1
# Out:
#      Unnamed: 0 property_type                            state        lat  \
# 0             1         house                 Estado de México  19.560181
# 1             2         house                       Nuevo León  25.688436
# 2             3     apartment                         Guerrero  16.767704
# 3             4     apartment                         Guerrero  16.829782
# 4             5         house  Veracruz de Ignacio de la Llave        NaN
# ..          ...           ...                              ...        ...
# 695         696         house                          Morelos        NaN
# 696         697         house                          Yucatán  21.050653
# 697         698         house                          Yucatán  21.343796
# 698         699     apartment                       Nuevo León        NaN
# 699         700         house                        Querétaro  20.587378
#
#             lon  area_m2    price_usd
# 0    -99.233528      150   $67,965.56
# ...

# %%
df2
# Out:
#      Unnamed: 0 property_type             state        lat         lon  \
# 0             1     apartment        Nuevo León  25.721081 -100.345581
# 1             2     apartment            Puebla        NaN         NaN
# 2             3         house           Morelos  23.634501 -102.552788
# 3             4         house           Morelos        NaN         NaN
# 4             5         house            Puebla        NaN         NaN
# ..          ...           ...               ...        ...         ...
# 695         696         house           Morelos  18.917542  -98.963181
# 696         697         house  Distrito Federal  19.472128  -99.146697
# 697         698         house  Estado de México  19.234984  -99.558175
# 698         699         house            Puebla  18.918714  -98.426639
# 699         700         house           Yucatán  21.075163  -89.516731
#
#      area_m2  price_mxn
# 0         72    1300000
# 1        190    2500000
# 2        360    5300000
# ...

# %%
df3
# Out:
#      Unnamed: 0 property_type  \
# 0             1     apartment
# 1             2         house
# 2             3         house
# 3             4         house
# 4             5     apartment
# ..          ...           ...
# 695         696         house
# 696         697         house
# 697         698         house
# 698         699         house
# 699         700         house
#
#                                place_with_parent_names  \
# 0    |México|Distrito Federal|Gustavo A. Madero|Acu...
# 1             |México|Estado de México|Toluca|Metepec|
# 2    |México|Estado de México|Toluca|Toluca de Lerd...
# 3          |México|Morelos|Temixco|Burgos Bugambilias|
# 4    |México|Veracruz de Ignacio de la Llave|Veracruz|
# ..                                                 ...
# 695  |México|Jalisco|Tlajomulco de Zúñiga|Tlajomulc...
# 696                          |México|Morelos|Jiutepec|
# 697                            |México|Yucatán|Mérida|
# ...

# %%
df1.shape
# Out:
# (700, 7)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     700 non-null    int64
#  1   property_type  700 non-null    object
#  2   state          700 non-null    object
#  3   lat            583 non-null    float64
#  4   lon            583 non-null    float64
#  5   area_m2        700 non-null    int64
#  6   price_usd      700 non-null    object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 38.4+ KB

# %%
df1.head()
# Out:
#    Unnamed: 0 property_type                            state        lat  \
# 0           1         house                 Estado de México  19.560181
# 1           2         house                       Nuevo León  25.688436
# 2           3     apartment                         Guerrero  16.767704
# 3           4     apartment                         Guerrero  16.829782
# 4           5         house  Veracruz de Ignacio de la Llave        NaN
#
#           lon  area_m2   price_usd
# 0  -99.233528      150  $67,965.56
# 1 -100.198807      186  $63,223.78
# 2  -99.764383       82  $84,298.37
# 3  -99.911012      150  $94,308.80
# 4         NaN      175  $94,835.67

# %%
df1 = df1.drop("Unnamed: 0", axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  700 non-null    object
#  1   state          700 non-null    object
#  2   lat            583 non-null    float64
#  3   lon            583 non-null    float64
#  4   area_m2        700 non-null    int64
#  5   price_usd      700 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 32.9+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     700 non-null    int64
#  1   property_type  700 non-null    object
#  2   state          700 non-null    object
#  3   lat            571 non-null    float64
#  4   lon            571 non-null    float64
#  5   area_m2        700 non-null    int64
#  6   price_mxn      700 non-null    int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 38.4+ KB

# %%
df2=df2.drop("Unnamed: 0", axis=1)

# %%
df3 = df3.drop("Unnamed: 0", axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  700 non-null    object
#  1   state          700 non-null    object
#  2   lat            583 non-null    float64
#  3   lon            583 non-null    float64
#  4   area_m2        700 non-null    int64
#  5   price_usd      700 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 32.9+ KB

# %%
df1.head(10)
# Out:
#   property_type                            state        lat         lon  \
# 0         house                 Estado de México  19.560181  -99.233528
# 1         house                       Nuevo León  25.688436 -100.198807
# 2     apartment                         Guerrero  16.767704  -99.764383
# 3     apartment                         Guerrero  16.829782  -99.911012
# 4         house  Veracruz de Ignacio de la Llave        NaN         NaN
# 5         house                          Yucatán  21.052583  -89.538639
# 6         house                        Querétaro  20.716315 -100.452503
# 7         house                        Querétaro        NaN         NaN
# 8         house                       Nuevo León        NaN         NaN
# 9         house                          Morelos  18.812605  -98.954826
#
#    area_m2    price_usd
# 0      150   $67,965.56
# 1      186   $63,223.78
# 2       82   $84,298.37
# 3      150   $94,308.80
# 4      175   $94,835.67
# ...

# %%
df1.dropna(inplace= True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 583 entries, 0 to 699
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  583 non-null    object
#  1   state          583 non-null    object
#  2   lat            583 non-null    float64
#  3   lon            583 non-null    float64
#  4   area_m2        583 non-null    int64
#  5   price_usd      583 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 31.9+ KB

# %%
df1["price_usd"].head()
# Out:
# 0     $67,965.56
# 1     $63,223.78
# 2     $84,298.37
# 3     $94,308.80
# 5    $105,191.37
# Name: price_usd, dtype: object

# %%
df1["price_usd"] = (
    df1["price_usd"]
    .str.replace("$", "", regex=False)
    .str.replace(",", "")
    .astype(float)
)

# %%
df1["price_usd"].head()
# Out:
# 0     67965.56
# 1     63223.78
# 2     84298.37
# 3     94308.80
# 5    105191.37
# Name: price_usd, dtype: float64

# %%
df2.dropna(inplace=True)

# %%
df2["price_usd"] = (df2["price_mxn"]/19).round(2)

# %%
df2.drop(columns=["price_mxn"], inplace = True)

# %%
df2.head()
# Out:
#   property_type             state        lat         lon  area_m2  price_usd
# 0     apartment        Nuevo León  25.721081 -100.345581       72   68421.05
# 2         house           Morelos  23.634501 -102.552788      360  278947.37
# 6     apartment  Estado de México  19.272040  -99.572013       85   65789.47
# 7         house   San Luis Potosí  22.138882 -100.996510      158  111578.95
# 8     apartment  Distrito Federal  19.394558  -99.129707       65   39904.74

# %%
df3.head()
# Out:
#   property_type                            place_with_parent_names  \
# 0     apartment  |México|Distrito Federal|Gustavo A. Madero|Acu...
# 1         house           |México|Estado de México|Toluca|Metepec|
# 2         house  |México|Estado de México|Toluca|Toluca de Lerd...
# 3         house        |México|Morelos|Temixco|Burgos Bugambilias|
# 4     apartment  |México|Veracruz de Ignacio de la Llave|Veracruz|
#
#                   lat-lon  area_m2  price_usd
# 0     19.52589,-99.151703       71   48550.59
# 1  19.2640539,-99.5727534      233  168636.73
# 2    19.268629,-99.671722      300   86932.69
# 3                     NaN      275  263432.41
# 4    19.511938,-96.871956       84   68508.67

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   property_type            700 non-null    object
#  1   place_with_parent_names  700 non-null    object
#  2   lat-lon                  582 non-null    object
#  3   area_m2                  700 non-null    int64
#  4   price_usd                700 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 27.5+ KB

# %%
df3.dropna(inplace= True)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 582 entries, 0 to 699
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   property_type            582 non-null    object
#  1   place_with_parent_names  582 non-null    object
#  2   lat-lon                  582 non-null    object
#  3   area_m2                  582 non-null    int64
#  4   price_usd                582 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 27.3+ KB

# %%
df3[["lat", "lon"]] = df3["lat-lon"].str.split(",", expand=True)

# %%
df3.head()
# Out:
#   property_type                            place_with_parent_names  \
# 0     apartment  |México|Distrito Federal|Gustavo A. Madero|Acu...
# 1         house           |México|Estado de México|Toluca|Metepec|
# 2         house  |México|Estado de México|Toluca|Toluca de Lerd...
# 4     apartment  |México|Veracruz de Ignacio de la Llave|Veracruz|
# 5         house                       |México|Jalisco|Guadalajara|
#
#                   lat-lon  area_m2  price_usd         lat          lon
# 0     19.52589,-99.151703       71   48550.59    19.52589   -99.151703
# 1  19.2640539,-99.5727534      233  168636.73  19.2640539  -99.5727534
# 2    19.268629,-99.671722      300   86932.69   19.268629   -99.671722
# 4    19.511938,-96.871956       84   68508.67   19.511938   -96.871956
# 5   20.689157,-103.366728      175  102763.00   20.689157  -103.366728

# %%
df3["state"] =  df3["place_with_parent_names"].str.split("|", expand=True)[2]

# %%
df3.head()
# Out:
#   property_type                            place_with_parent_names  \
# 0     apartment  |México|Distrito Federal|Gustavo A. Madero|Acu...
# 1         house           |México|Estado de México|Toluca|Metepec|
# 2         house  |México|Estado de México|Toluca|Toluca de Lerd...
# 4     apartment  |México|Veracruz de Ignacio de la Llave|Veracruz|
# 5         house                       |México|Jalisco|Guadalajara|
#
#                   lat-lon  area_m2  price_usd         lat          lon  \
# 0     19.52589,-99.151703       71   48550.59    19.52589   -99.151703
# 1  19.2640539,-99.5727534      233  168636.73  19.2640539  -99.5727534
# 2    19.268629,-99.671722      300   86932.69   19.268629   -99.671722
# 4    19.511938,-96.871956       84   68508.67   19.511938   -96.871956
# 5   20.689157,-103.366728      175  102763.00   20.689157  -103.366728
#
#                              state
# 0                 Distrito Federal
# 1                 Estado de México
# ...

# %%
df3.drop(columns=["place_with_parent_names", "lat-lon"], inplace=True)

# %%
df3.head()
# Out:
#   property_type  area_m2  price_usd         lat          lon  \
# 0     apartment       71   48550.59    19.52589   -99.151703
# 1         house      233  168636.73  19.2640539  -99.5727534
# 2         house      300   86932.69   19.268629   -99.671722
# 4     apartment       84   68508.67   19.511938   -96.871956
# 5         house      175  102763.00   20.689157  -103.366728
#
#                              state
# 0                 Distrito Federal
# 1                 Estado de México
# 2                 Estado de México
# 4  Veracruz de Ignacio de la Llave
# 5                          Jalisco

# %%
df =  pd.concat([df1, df2, df3])

# %%
df.shape
# Out:
# (1736, 6)
